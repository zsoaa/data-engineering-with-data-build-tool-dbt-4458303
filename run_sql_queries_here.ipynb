# %%
import duckdb
import pandas as pd

# %%
sql_query = '''
select * from silver_violation_tickets
--show tables
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#        summons_number issue_date  violation_code  is_manhattan_96th_st_below  \
# 0          9010912681 2022-10-11              17                       False
# 1          4858762841 2023-08-21              36                       False
# 2          4854645684 2023-07-26              36                       False
# 3          9044582707 2023-04-10              21                       False
# 4          9041503330 2023-03-21              21                       False
# ...               ...        ...             ...                         ...
# 99995      1484690643 2023-07-09              27                       False
# 99996      9045553041 2023-05-09              50                       False
# 99997      8666741156 2023-04-25              27                       False
# 99998      9067387708 2023-08-02              50                       False
# 99999      9060360837 2023-06-07              50                       False
#
#       issuing_agency  violation_location  violation_precinct  issuer_precinct  \
# 0                  T                50.0                  50               50
# 1                  V                 NaN                   0                0
# 2                  V                 NaN                   0                0
# 3                  T                79.0                  79               79
# 4                  T                26.0                  26               26
# ...              ...                 ...                 ...              ...
# 99995              K               123.0                 123                5
# 99996              T                19.0                  19               19
# 99997              T                72.0                  72               72
# 99998              T                 9.0                   9                9
# 99999              T                71.0                  71               71
#
#        issuer_code issuer_command issuer_squad violation_time  \
# 0           365910           T201            D          0825A
# 1                0           None         None          1036A
# 2                0           None         None          0126P
# 3           370326           T301            H          0924A
# 4           373097           T103            C          1155A
# ...            ...            ...          ...            ...
# 99995       161086              5            0          0348P
# 99996       376151           T103           PP          0122P
# 99997       367352           T302            B          1101A
# 99998       373669           T102            I          0857A
# 99999       355147           T302            N          0748A
#
#       violation_county violation_legal_code  fee_usd
# 0                   BX                  NaN     95.0
# 1                   BK                 True     50.0
# 2                   QN                 True     50.0
# 3                    K                  NaN     65.0
# 4                   NY                  NaN     65.0
# ...                ...                  ...      ...
# 99995                R                  NaN    180.0
# 99996               NY                  NaN    115.0
# 99997                K                  NaN    180.0
# 99998               NY                  NaN    115.0
# 99999                K                  NaN    115.0
#
# [100000 rows x 15 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sql_query_1 = '''create or replace table parking_violation_codes
as
select * from read_csv_auto(
  'data/dof_parking_violation_codes.csv',
  normalize_names=true)
'''

sql_query_2 = '''create or replace table parking_violations_2023
as
select * from read_csv_auto(
  'data/parking_violations_issued_fiscal_year_2023_sample.csv',
  normalize_names=true)
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    con.sql(sql_query_1)
    con.sql(sql_query_2)

# %%
sql_query = '''
select * from parking_violations_2023 limit 5
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    summons_number registration_state plate_type issue_date  violation_code  \
# 0      9010912681                 CA        PAS 2022-10-11              17
# 1      4858762841                 NY        PAS 2023-08-21              36
# 2      4854645684                 FL        PAS 2023-07-26              36
# 3      9044582707                 NY        PAS 2023-04-10              21
# 4      9041503330                 NY        PAS 2023-03-21              21
#
#   vehicle_body_type vehicle_make issuing_agency  vehicle_expiration_date  \
# 0              SUBN         FORD              T                 20220788
# 1              4DSD        HONDA              V                        0
# 2                UT          BMW              V                        0
# 3              SUBN        SUBAR              T                 20231217
# 4              4DSD        CHEVR              T                 20250320
#
#    violation_location  ...  from_hours_in_effect  to_hours_in_effect  \
# 0                50.0  ...                 0700A               0400P
# 1                 NaN  ...                  None                None
# 2                 NaN  ...                  None                None
# 3                79.0  ...                 0900A               1030A
# 4                26.0  ...                 1100A               1230A
#
#    vehicle_color unregistered_vehicle vehicle_year meter_number  \
# 0          BLACK                  NaN            0         None
# 1             GY                  NaN         2003         None
# 2            WHI                  NaN         2022         None
# 3             GY                  NaN         2017         None
# 4             BK                  NaN         2018         None
#
#   feet_from_curb no_standing_or_stopping_violation hydrant_violation  \
# 0              0                              None              None
# 1              0                              None              None
# 2              0                              None              None
# 3              0                              None              None
# 4              0                              None              None
#
#    double_parking_violation
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
#
# [5 rows x 34 columns]
